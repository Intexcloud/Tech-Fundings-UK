# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sea

# %%
df = pd.read_csv('tech_fundings.csv')

# %%
df
# Out:
#       index         Company                      Website          Region  \
# 0         1        Internxt        https://internxt.com/           Spain
# 1         2        Dockflow         https://dockflow.com         Belgium
# 2         3       api.video            https://api.video          France
# 3         4         Buck.ai             https://buck.ai/   United States
# 4         5       Prodsight     https://www.prodsight.ai  United Kingdom
# ...     ...             ...                          ...             ...
# 3570   3571         Headout      https://www.headout.com   United States
# 3571   3572            OLIO          https://olioex.com/  United Kingdom
# 3572   3573  Trees for Life  https://treesforlife.org.uk  United Kingdom
# 3573   3574     Britishvolt     https://britishvolt.com/  United Kingdom
# 3574   3575         Greenly   https://www.greenly.earth/          France
#
#                      Vertical Funding Amount (USD) Funding Stage Funding Date
# ...

# %%
df.isnull().sum()
# Out:
# index                    0
# Company                  0
# Website                  0
# Region                  12
# Vertical                 0
# Funding Amount (USD)     0
# Funding Stage            0
# Funding Date             0
# dtype: int64

# %%
df.dtypes
# Out:
# index                    int64
# Company                 object
# Website                 object
# Region                  object
# Vertical                object
# Funding Amount (USD)    object
# Funding Stage           object
# Funding Date            object
# dtype: object

# %%
df.drop(columns = ['index'], inplace = True )

# %%
df
# Out:
#              Company                      Website          Region  \
# 0           Internxt        https://internxt.com/           Spain
# 1           Dockflow         https://dockflow.com         Belgium
# 2          api.video            https://api.video          France
# 3            Buck.ai             https://buck.ai/   United States
# 4          Prodsight     https://www.prodsight.ai  United Kingdom
# ...              ...                          ...             ...
# 3570         Headout      https://www.headout.com   United States
# 3571            OLIO          https://olioex.com/  United Kingdom
# 3572  Trees for Life  https://treesforlife.org.uk  United Kingdom
# 3573     Britishvolt     https://britishvolt.com/  United Kingdom
# 3574         Greenly   https://www.greenly.earth/          France
#
#                      Vertical Funding Amount (USD) Funding Stage Funding Date
# 0                  Blockchain               278940          Seed       Jan-20
# ...

# %%
df.drop(columns = ['Website'], inplace= True)

# %%
df
# Out:
#              Company          Region                 Vertical  \
# 0           Internxt           Spain               Blockchain
# 1           Dockflow         Belgium                Logistics
# 2          api.video          France           Developer APIs
# 3            Buck.ai   United States  Artificial Intelligence
# 4          Prodsight  United Kingdom  Artificial Intelligence
# ...              ...             ...                      ...
# 3570         Headout   United States                   Travel
# 3571            OLIO  United Kingdom                 Wellness
# 3572  Trees for Life  United Kingdom                 Wellness
# 3573     Britishvolt  United Kingdom                 Wellness
# 3574         Greenly          France                 Wellness
#
#      Funding Amount (USD) Funding Stage Funding Date
# 0                  278940          Seed       Jan-20
# 1                  292244          Seed       Jan-20
# 2                  300000          Seed       Jan-20
# ...

# %%
df2 = df.query("Region == 'United Kingdom'")
df2
# Out:
#              Company          Region                 Vertical  \
# 4          Prodsight  United Kingdom  Artificial Intelligence
# 17             Float  United Kingdom             B2B Software
# 28           Griffin  United Kingdom                  FinTech
# 29     Coda Platform  United Kingdom                   Gaming
# 31            Teller  United Kingdom                  FinTech
# ...              ...             ...                      ...
# 3561           LICKD  United Kingdom           Social Network
# 3568     StreetDrone  United Kingdom           Transportation
# 3571            OLIO  United Kingdom                 Wellness
# 3572  Trees for Life  United Kingdom                 Wellness
# 3573     Britishvolt  United Kingdom                 Wellness
#
#      Funding Amount (USD) Funding Stage Funding Date
# 4                  529013          Seed       Jan-20
# 17                1955982          Seed       Jan-20
# 28                3904358          Seed       Jan-20
# ...

# %%
df2.sort_values(by = 'Funding Date', ascending = True)
# Out:
#                 Company          Region                 Vertical  \
# 215          ContentCal  United Kingdom             B2B Software
# 210       Ably Realtime  United Kingdom          Cloud Computing
# 211              Yapily  United Kingdom                  FinTech
# 222            Glassbox  United Kingdom          Cloud Computing
# 253              Gousto  United Kingdom        Food and Beverage
# ...                 ...             ...                      ...
# 3314  Isotropic Systems  United Kingdom             B2B Software
# 3287      ContractPodAi  United Kingdom  Artificial Intelligence
# 3572     Trees for Life  United Kingdom                 Wellness
# 3429         Multiverse  United Kingdom                Education
# 3573        Britishvolt  United Kingdom                 Wellness
#
#      Funding Amount (USD) Funding Stage Funding Date
# 215                185000          Seed       Apr-20
# 210               7000000      Series A       Apr-20
# ...

# %%
df2.shape
# Out:
# (319, 6)

# %%
df2.head(10)
# Out:
#           Company          Region                 Vertical  \
# 4       Prodsight  United Kingdom  Artificial Intelligence
# 17          Float  United Kingdom             B2B Software
# 28        Griffin  United Kingdom                  FinTech
# 29  Coda Platform  United Kingdom                   Gaming
# 31         Teller  United Kingdom                  FinTech
# 35           Juro  United Kingdom             B2B Software
# 36          Pando  United Kingdom              Health Care
# 41   Upgrade Pack  United Kingdom                   Travel
# 42       Shipamax  United Kingdom                Logistics
# 53       Yumpingo  United Kingdom             B2B Software
#
#    Funding Amount (USD) Funding Stage Funding Date
# 4                529013          Seed       Jan-20
# 17              1955982          Seed       Jan-20
# 28              3904358          Seed       Jan-20
# 29              4000000          Seed       Jan-20
# 31              4000000          Seed       Jan-20
# ...

# %%
df2.to_csv('Company Fundings In UK.csv', index= False)
df2 = pd.read_csv('Company Fundings In UK.csv')
df2
# Out:
#             Company          Region                 Vertical  \
# 0         Prodsight  United Kingdom  Artificial Intelligence
# 1             Float  United Kingdom             B2B Software
# 2           Griffin  United Kingdom                  FinTech
# 3     Coda Platform  United Kingdom                   Gaming
# 4            Teller  United Kingdom                  FinTech
# ..              ...             ...                      ...
# 314           LICKD  United Kingdom           Social Network
# 315     StreetDrone  United Kingdom           Transportation
# 316            OLIO  United Kingdom                 Wellness
# 317  Trees for Life  United Kingdom                 Wellness
# 318     Britishvolt  United Kingdom                 Wellness
#
#      Funding Amount (USD) Funding Stage Funding Date
# 0                  529013          Seed       Jan-20
# 1                 1955982          Seed       Jan-20
# 2                 3904358          Seed       Jan-20
# ...
